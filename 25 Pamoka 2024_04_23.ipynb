# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

import time
import selenium
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup

# %%
puslapio_nr = [2]
opcijos=Options()
data=[]

for puslapis in puslapio_nr:
    url = f'https://autoplius.lt/skelbimai/naudoti-automobiliai?page_nr={puslapis}'
    driver=webdriver.Chrome(options=opcijos)
    driver.get(url)
    time.sleep(30)
    source=driver.page_source
    bs=BeautifulSoup(source,'html.parser')
    ResultSet=bs.find_all('div',{'class':'announcement-content'})
    print(len(ResultSet))

# for ciklas

    driver.close()
# Out:
# 20

# %%
puslapio_nr = [2]
opcijos=Options()
data=[]

for puslapis in puslapio_nr:
    url = f'https://autoplius.lt/skelbimai/naudoti-automobiliai?page_nr={puslapis}'
    driver=webdriver.Chrome(options=opcijos)
    driver.get(url)
    time.sleep(30)
    source=driver.page_source
    bs=BeautifulSoup(source,'html.parser')
    ResultSet=bs.find_all('div',{'class':'announcement-content'})
    print(len(ResultSet))

    for skelbimas in ResultSet:
        if len(skelbimas) > 0:
            try:
                gamintojasModelis_element= skelbimas.find('div', {'class':'announcement-body-heading'})
                tag = gamintojasModelis_element.find('div', {'class':'announcement-title'})
                gamintojasModelis = tag.text.strip() # f dalies nedarem, nes pakako ir cia pasidaryti stripinima.
                
                pagaminimoData_element= skelbimas.find('div', {'class':'announcement-title-parameters'}).find('div',{'class':'announcement-parameters'})
                tag1 = pagaminimoData_element.text
                pagaminimoData = (pagaminimoData_element.contents)[1].text

                kebulas_element= skelbimas.find('div', {'class':'announcement-title-parameters'}).find('div',{'class':'announcement-parameters'})
                tag2 = kebulas_element.text
                kebulas = (kebulas_element.contents)[3].text

                kaina_element= skelbimas.find('div', {'class':'announcement-body-heading'}).find('div',{'class':'pricing-container has-loan-price'}).find('div',{'class':'announcement-pricing-info'}).find('strong')
                kaina = kaina_element.text.strip()

                kuras_element= skelbimas.find('div',{'class':'announcement-parameters-block'}).find('div',{'class':'announcement-parameters'}).find('span')
                kuras = kuras_element.text.replace('\n','').strip()

                pavaru_deze_element= skelbimas.find('div',{'class':'announcement-parameters-block'}).find('div',{'class':'announcement-parameters'})
                pavaru_deze = pavaru_deze_element.text.split('\n')[3] # pasidariau sarasa, ji isslitinau per \n ir paemiau 4 elementa

                variklis_element= skelbimas.find('div',{'class':'announcement-parameters-block'}).find('div',{'class':'announcement-parameters'})
                variklis = variklis_element.text.split('\n')[5].split(',')[0].strip()

                kw_element= skelbimas.find('div',{'class':'announcement-parameters-block'}).find('div',{'class':'announcement-parameters'})
                kw = kw_element.text.split('\n')[5].split(',')[1].strip()

                rida_element= skelbimas.find('div',{'class':'announcement-parameters-block'}).find('div',{'class':'announcement-parameters'})
                rida = rida_element.text.split('\n')[6].strip()

                miestas_element= skelbimas.find('div',{'class':'announcement-parameters-block'}).find('div',{'class':'announcement-parameters'})
                miestas = miestas_element.text.split('\n')[7].strip()

                d = {'Gamintojas ir modelis':gamintojasModelis,'Pagaminimo data':pagaminimoData, 'Kėbulo tipas':kebulas, 'Kaina':kaina, 'Kuros tipas':kuras, 'Pavarų dėžė':pavaru_deze, 'Variklio turis':variklis, 'Variklio galia':kw, 'Rida':rida, 'Miestas':miestas}
                data.append(d)
                print(d)

            except Exception as klaida:
                print(klaida)   
        else:
            print("nenurodyta")
    driver.close() 

df = pd.DataFrame(data=data)
df.to_csv('Auto_plius 2024_04_23.csv', header=True, index=False)
# Out:
# 0

# %%
for skelbimas in ResultSet:
    if len(skelbimas) > 0:
        try:
            gamintojasModelis_element= skelbimas.find('div', {'class':'announcement-body-heading'})
            tag = gamintojasModelis_element.find('div', {'class':'announcement-title'})
            gamintojasModelis = tag.text.strip() # f dalies nedarem, nes pakako ir cia pasidaryti stripinima.
            
            pagaminimoData_element= skelbimas.find('div', {'class':'announcement-title-parameters'}).find('div',{'class':'announcement-parameters'})
            tag1 = pagaminimoData_element.text
            pagaminimoData = (pagaminimoData_element.contents)[1].text

            kebulas_element= skelbimas.find('div', {'class':'announcement-title-parameters'}).find('div',{'class':'announcement-parameters'})
            tag2 = kebulas_element.text
            kebulas = (kebulas_element.contents)[3].text

            kaina_element= skelbimas.find('div', {'class':'announcement-body-heading'}).find('div',{'class':'pricing-container has-loan-price'}).find('div',{'class':'announcement-pricing-info'}).find('strong')
            kaina = kaina_element.text.strip()

            kuras_element= skelbimas.find('div',{'class':'announcement-parameters-block'}).find('div',{'class':'announcement-parameters'}).find('span')
            kuras = kuras_element.text.replace('\n','').strip()

            pavaru_deze_element= skelbimas.find('div',{'class':'announcement-parameters-block'}).find('div',{'class':'announcement-parameters'})
            pavaru_deze = pavaru_deze_element.text.split('\n')[3] # pasidariau sarasa, ji isslitinau per \n ir paemiau 4 elementa

            variklis_element= skelbimas.find('div',{'class':'announcement-parameters-block'}).find('div',{'class':'announcement-parameters'})
            variklis = variklis_element.text.split('\n')[5].split(',')[0].strip()

            kw_element= skelbimas.find('div',{'class':'announcement-parameters-block'}).find('div',{'class':'announcement-parameters'})
            kw = kw_element.text.split('\n')[5].split(',')[1].strip()

            rida_element= skelbimas.find('div',{'class':'announcement-parameters-block'}).find('div',{'class':'announcement-parameters'})
            rida = rida_element.text.split('\n')[6].strip()

            miestas_element= skelbimas.find('div',{'class':'announcement-parameters-block'}).find('div',{'class':'announcement-parameters'})
            miestas = miestas_element.text.split('\n')[7].strip()

            d = {'Gamintojas ir modelis':gamintojasModelis,'Pagaminimo data':pagaminimoData, 'Kėbulo tipas':kebulas, 'Kaina':kaina, 'Kuros tipas':kuras, 'Pavarų dėžė':pavaru_deze, 'Variklio turis':variklis, 'Variklio galia':kw, 'Rida':rida, 'Miestas':miestas}
            data.append(d)
            print(d)

        except Exception as klaida:
            print(klaida)   
    else:
        print("nenurodyta")
# Out:
# {'Gamintojas ir modelis': 'Ford Transit Custom', 'Pagaminimo data': '2015-11', 'Kėbulo tipas': 'Keleivinis mikroautobusas', 'Kaina': '6 500 €', 'Kuros tipas': 'Dyzelinas', 'Pavarų dėžė': 'Mechaninė', 'Variklio turis': '2.2 l.', 'Variklio galia': '92  kW', 'Rida': '300 006 km', 'Miestas': 'Šiauliai'}
# {'Gamintojas ir modelis': 'Volkswagen Scirocco', 'Pagaminimo data': '2013', 'Kėbulo tipas': 'Kupė (Coupe)', 'Kaina': '8 200 €', 'Kuros tipas': 'Dyzelinas', 'Pavarų dėžė': 'Automatinė', 'Variklio turis': '2.0 l.', 'Variklio galia': '103  kW', 'Rida': '180 000 km', 'Miestas': 'Kaunas'}
# {'Gamintojas ir modelis': 'Toyota Prius', 'Pagaminimo data': '2010', 'Kėbulo tipas': 'Hečbekas', 'Kaina': '8 300 €', 'Kuros tipas': 'Benzinas / elektra', 'Pavarų dėžė': 'Automatinė', 'Variklio turis': '1.8 l.', 'Variklio galia': '73  kW', 'Rida': '287 600 km', 'Miestas': 'Jurbarkas'}
# {'Gamintojas ir modelis': 'BMW X6', 'Pagaminimo data': '2010-08', 'Kėbulo tipas': 'Visureigis / Krosoveris', 'Kaina': '11 700 €', 'Kuros tipas': 'Dyzelinas', 'Pavarų dėžė': 'Automatinė', 'Variklio turis': '3.0 l.', 'Variklio galia': '210  kW', 'Rida': '279 580 km', 'Miestas': 'Vilnius'}
# {'Gamintojas ir modelis': 'BMW X3', 'Pagaminimo data': '2016', 'Kėbulo tipas': 'Visureigis / Krosoveris', 'Kaina': '11 850 €', 'Kuros tipas': 'Benzinas', 'Pavarų dėžė': 'Automatinė', 'Variklio turis': '2.0 l.', 'Variklio galia': '180  kW', 'Rida': '100 254 km', 'Miestas': 'Vilnius'}
# {'Gamintojas ir modelis': 'Mercedes-Benz CLS350', 'Pagaminimo data': '2011-03', 'Kėbulo tipas': 'Kupė (Coupe)', 'Kaina': '12 400 €', 'Kuros tipas': 'Dyzelinas', 'Pavarų dėžė': 'Automatinė', 'Variklio turis': '3.0 l.', 'Variklio galia': '195  kW', 'Rida': '283 000 km', 'Miestas': 'Kaunas'}
# {'Gamintojas ir modelis': 'Volkswagen Golf', 'Pagaminimo data': '2015-05', 'Kėbulo tipas': 'Hečbekas', 'Kaina': '13 500 €', 'Kuros tipas': 'Dyzelinas', 'Pavarų dėžė': 'Automatinė', 'Variklio turis': '2.0 l.', 'Variklio galia': '135  kW', 'Rida': '175 000 km', 'Miestas': 'Kaunas'}
# {'Gamintojas ir modelis': 'BMW 630 Gran Turismo', 'Pagaminimo data': '2018-12', 'Kėbulo tipas': 'Hečbekas', 'Kaina': '27 500 €', 'Kuros tipas': 'Dyzelinas', 'Pavarų dėžė': 'Automatinė', 'Variklio turis': '3.0 l.', 'Variklio galia': '195  kW', 'Rida': '200 000 km', 'Miestas': 'Marijampolė'}
# 'NoneType' object has no attribute 'find'
# {'Gamintojas ir modelis': 'Toyota Avensis', 'Pagaminimo data': '2004', 'Kėbulo tipas': 'Sedanas', 'Kaina': '1 700 €', 'Kuros tipas': 'Dyzelinas', 'Pavarų dėžė': 'Mechaninė', 'Variklio turis': '2.0 l.', 'Variklio galia': '85  kW', 'Rida': '270 000 km', 'Miestas': 'Vilnius'}
# {'Gamintojas ir modelis': 'Volkswagen Transporter', 'Pagaminimo data': '2007-02', 'Kėbulo tipas': 'Krovininis mikroautobusas', 'Kaina': '2 380 €', 'Kuros tipas': 'Dyzelinas', 'Pavarų dėžė': 'Mechaninė', 'Variklio turis': '2.5 l.', 'Variklio galia': '96  kW', 'Rida': '290 000 km', 'Miestas': 'Joniškis'}
# {'Gamintojas ir modelis': 'Ford Tourneo Connect', 'Pagaminimo data': '2012-12', 'Kėbulo tipas': 'Vienatūris', 'Kaina': '2 700 €', 'Kuros tipas': 'Dyzelinas', 'Pavarų dėžė': 'Mechaninė', 'Variklio turis': '1.8 l.', 'Variklio galia': '66  kW', 'Rida': '135 000 km', 'Miestas': 'Vilnius'}
# {'Gamintojas ir modelis': 'Toyota Corolla', 'Pagaminimo data': '2010-06', 'Kėbulo tipas': 'Sedanas', 'Kaina': '3 800 €', 'Kuros tipas': 'Benzinas', 'Pavarų dėžė': 'Automatinė', 'Variklio turis': '1.6 l.', 'Variklio galia': '91  kW', 'Rida': '265 000 km', 'Miestas': 'Vilnius'}
# {'Gamintojas ir modelis': 'Toyota Prius', 'Pagaminimo data': '2007', 'Kėbulo tipas': 'Hečbekas', 'Kaina': '3 950 €', 'Kuros tipas': 'Benzinas / elektra', 'Pavarų dėžė': 'Automatinė', 'Variklio turis': '1.5 l.', 'Variklio galia': '56  kW', 'Rida': '187 000 km', 'Miestas': 'Kaunas'}
# {'Gamintojas ir modelis': 'Mercedes-Benz C220', 'Pagaminimo data': '2009-09', 'Kėbulo tipas': 'Universalas', 'Kaina': '4 550 €', 'Kuros tipas': 'Dyzelinas', 'Pavarų dėžė': 'Automatinė', 'Variklio turis': '2.1 l.', 'Variklio galia': '125  kW', 'Rida': '288 000 km', 'Miestas': 'Telšiai'}
# {'Gamintojas ir modelis': 'Toyota RAV4', 'Pagaminimo data': '2007-11', 'Kėbulo tipas': 'Visureigis / Krosoveris', 'Kaina': '5 000 €', 'Kuros tipas': 'Benzinas', 'Pavarų dėžė': 'Automatinė', 'Variklio turis': '2.0 l.', 'Variklio galia': '112  kW', 'Rida': '247 000 km', 'Miestas': 'Vilnius'}
# {'Gamintojas ir modelis': 'Toyota Avensis', 'Pagaminimo data': '2010-09', 'Kėbulo tipas': 'Universalas', 'Kaina': '5 150 €', 'Kuros tipas': 'Dyzelinas', 'Pavarų dėžė': 'Automatinė', 'Variklio turis': '2.2 l.', 'Variklio galia': '110  kW', 'Rida': '194 000 km', 'Miestas': 'Vilnius'}
# {'Gamintojas ir modelis': 'Volkswagen Phaeton', 'Pagaminimo data': '2008-12', 'Kėbulo tipas': 'Sedanas', 'Kaina': '5 900 €', 'Kuros tipas': 'Dyzelinas', 'Pavarų dėžė': 'Automatinė', 'Variklio turis': '3.0 l.', 'Variklio galia': '171  kW', 'Rida': '234 753 km', 'Miestas': 'Vilnius'}
# {'Gamintojas ir modelis': 'Volkswagen CC', 'Pagaminimo data': '2011-11', 'Kėbulo tipas': 'Sedanas', 'Kaina': '6 400 €', 'Kuros tipas': 'Dyzelinas', 'Pavarų dėžė': 'Mechaninė', 'Variklio turis': '2.0 l.', 'Variklio galia': '103  kW', 'Rida': '197 000 km', 'Miestas': 'Anykščiai'}
# {'Gamintojas ir modelis': 'BMW X5', 'Pagaminimo data': '2008-10', 'Kėbulo tipas': 'Visureigis / Krosoveris', 'Kaina': '6 500 €', 'Kuros tipas': 'Benzinas', 'Pavarų dėžė': 'Automatinė', 'Variklio turis': '4.8 l.', 'Variklio galia': '265  kW', 'Rida': '265 000 km', 'Miestas': 'Vilnius'}

# %%
# Vieno elemento paieska

data=[]

for skelbimas in ResultSet:
    if len(skelbimas) > 0:
        try:

            gamintojas_element= skelbimas.find('div', {'class':'announcement-body-heading'})
            tag = gamintojas_element.find('div', {'class':'announcement-title'})
            gamintojas = tag.text.split()[0]

            modelis_element= skelbimas.find('div', {'class':'announcement-body-heading'})
            tag = modelis_element.find('div', {'class':'announcement-title'})
            modelis = ' '.join(tag.text.split()[1:])

            d = {'Gamintojas':gamintojas, 'Modelis':modelis}
            data.append(d)
            print(d)
        
        except Exception as klaida:
            print(klaida)   
    else:
        print("nenurodyta")

df = pd.DataFrame(data=data)
df.to_csv('Auto_plius 2024_04_23.csv', header=True, index=False)
# Out:
# {'Gamintojas': 'Ford', 'Modelis': 'Transit Custom'}
# {'Gamintojas': 'Volkswagen', 'Modelis': 'Scirocco'}
# {'Gamintojas': 'Toyota', 'Modelis': 'Prius'}
# {'Gamintojas': 'BMW', 'Modelis': 'X6'}
# {'Gamintojas': 'BMW', 'Modelis': 'X3'}
# {'Gamintojas': 'Mercedes-Benz', 'Modelis': 'CLS350'}
# {'Gamintojas': 'Volkswagen', 'Modelis': 'Golf'}
# {'Gamintojas': 'BMW', 'Modelis': '630 Gran Turismo'}
# {'Gamintojas': 'Mitsubishi', 'Modelis': 'Carisma'}
# {'Gamintojas': 'Toyota', 'Modelis': 'Avensis'}
# {'Gamintojas': 'Volkswagen', 'Modelis': 'Transporter'}
# {'Gamintojas': 'Ford', 'Modelis': 'Tourneo Connect'}
# {'Gamintojas': 'Toyota', 'Modelis': 'Corolla'}
# {'Gamintojas': 'Toyota', 'Modelis': 'Prius'}
# {'Gamintojas': 'Mercedes-Benz', 'Modelis': 'C220'}
# {'Gamintojas': 'Toyota', 'Modelis': 'RAV4'}
# {'Gamintojas': 'Toyota', 'Modelis': 'Avensis'}
# {'Gamintojas': 'Volkswagen', 'Modelis': 'Phaeton'}
# {'Gamintojas': 'Volkswagen', 'Modelis': 'CC'}
# {'Gamintojas': 'BMW', 'Modelis': 'X5'}

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import time
import selenium
# import undetected_chromedriver as uc
from selenium import webdriver
# from selenium.webdriver.chrome.options import Options
from selenium.webdriver.firefox.options import Options
from bs4 import BeautifulSoup

# is Firefox narsykles paimant:

opcijos = Options()
opcijos.add_argument('--incognito')
# opcijos.add_argument('--headless')
# driver = uc.Chrome(options=opcijos)
driver = webdriver.Firefox(options=opcijos)

# %%
auto_plius = pd.read_csv("Auto_plius 2024_04_23.csv")
auto_plius
# Out:
#     Gamintojas         Modelis Pagaminimo data               Kėbulo tipas  \
# 0          BMW             320         2009-06                Universalas
# 1         Ford  Transit Custom         2015-11  Keleivinis mikroautobusas
# 2   Volkswagen        Scirocco            2013               Kupė (Coupe)
# 3       Toyota           Prius            2010                   Hečbekas
# 4          BMW              X5            2008    Visureigis / Krosoveris
# ..         ...             ...             ...                        ...
# 88  Volkswagen         Touareg         2010-11    Visureigis / Krosoveris
# 89  Volkswagen          Passat         2015-07                Universalas
# 90       Lexus         GS 300h            2014                    Sedanas
# 91       Lexus          IS 250            2016                    Sedanas
# 92        Fiat          Ducato         2016-01  Krovininis mikroautobusas
#
#        Kaina         Kuros tipas Pavarų dėžė Variklio turis Variklio galia  \
# 0    5 300 €           Dyzelinas  Automatinė         2.0 l.        130  kW
# 1    6 500 €           Dyzelinas   Mechaninė         2.2 l.         92  kW
# 2    8 200 €           Dyzelinas  Automatinė         2.0 l.        103  kW
# 3    8 300 €  Benzinas / elektra  Automatinė         1.8 l.         73  kW
# 4    9 350 €           Dyzelinas  Automatinė         3.0 l.        173  kW
# ..       ...                 ...         ...            ...            ...
# 88  11 500 €           Dyzelinas  Automatinė         3.0 l.        176  kW
# 89  12 500 €           Dyzelinas  Automatinė         2.0 l.        140  kW
# 90  12 950 €  Benzinas / elektra  Automatinė         2.5 l.        164  kW
# 91  14 000 €            Benzinas  Automatinė         2.5 l.        153  kW
# 92  14 300 €           Dyzelinas   Mechaninė         2.3 l.         96  kW
#
#           Rida    Miestas
# 0   278 335 km     Kaunas
# 1   300 006 km   Šiauliai
# 2   180 000 km     Kaunas
# 3   287 600 km  Jurbarkas
# 4   310 000 km    Vilnius
# ..         ...        ...
# 88  275 182 km    Vilnius
# 89  181 000 km   Klaipėda
# 90  400 000 km     Trakai
# 91  128 000 km    Vilnius
# 92  142 754 km    Vilnius
#
# [93 rows x 11 columns]

# %%
# jūsų atrankoje, kiek automobilių buvo su atomatu, mech, kokios jų buvo vidutinės kainos?

def nauja_kaina(eur):
    eurai = int(eur).replace(' ','').replace('€', '')
    return eurai

auto_plius['Kaina'] = auto_plius['Kaina'].apply(nauja_kaina)
auto_plius.head()

# vid_kaina = auto_plius.groupby(by='Pavarų dėžė')['Kaina'].mean()
# print(vid_kaina)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[374], line 7
#       4     eurai = int(eur).replace(' ','').replace('€', '')
#       5     return eurai
# ----> 7 auto_plius['Kaina'] = auto_plius['Kaina'].apply(nauja_kaina)
#       8 auto_plius.head()
#      10 # vid_kaina = auto_plius.groupby(by='Pavarų dėžė')['Kaina'].mean()
#      11 # print(vid_kaina)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\series.py:4915, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4780 def apply(
#    4781     self,
#    4782     func: AggFuncType,
#    (...)
#    4787     **kwargs,
#    4788 ) -> DataFrame | Series:
#    4789     """
#    4790     Invoke function on values of Series.
#    4791
#    (...)
#    4906     dtype: float64
#    4907     """
#    4908     return SeriesApply(
#    4909         self,
#    4910         func,
#    4911         convert_dtype=convert_dtype,
#    4912         by_row=by_row,
#    4913         args=args,
#    4914         kwargs=kwargs,
# -> 4915     ).apply()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[374], line 4, in nauja_kaina(eur)
#       3 def nauja_kaina(eur):
# ----> 4     eurai = int(eur).replace(' ','').replace('€', '')
#       5     return eurai
#
# ValueError: invalid literal for int() with base 10: '5 300 €'

# %%
# advanced: su pie plot atvaizduokite gamintojų užimamą rinkos dalį (5 didžiausi + visi kiti)
